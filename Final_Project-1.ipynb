# %% [markdown]
# # Part 1- Data Preprocessing

# %% [markdown]
# ## 1.1 Importing The Required Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1.2. Importing The Dataset

# %%
df=pd.read_excel("G:/CDAC/Project/default of credit card clients.xls")
df.head(10)
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
# 5   6      50000    1          1         2   37      0      0      0      0
# 6   7     500000    1          1         2   29      0      0      0      0
# 7   8     100000    2          2         2   23      0     -1     -1      0
# 8   9     140000    2          3         1   28      0      0      2      0
# 9  10      20000    1          3         2   35     -2     -2     -2     -2
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
# 5  ...      19394      19619      20024      2500      1815       657
# 6  ...     542653     483003     473944     55000     40000     38000
# 7  ...        221       -159        567       380       601         0
# 8  ...      12211      11793       3719      3329         0       432
# 9  ...          0      13007      13912         0         0         0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  DEFAULT_NEXT_MONTH
# 0         0         0         0                   1
# 1      1000         0      2000                   1
# 2      1000      1000      5000                   0
# 3      1100      1069      1000                   0
# 4      9000       689       679                   0
# 5      1000      1000       800                   0
# 6     20239     13750     13770                   0
# 7       581      1687      1542                   0
# 8      1000      1000      1000                   0
# 9     13007      1122         0                   0
#
# [10 rows x 25 columns]

# %%
df.tail()
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
#        PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 29995      0  ...      88004      31237      15980      8500     20000
# 29996     -1  ...       8979       5190          0      1837      3526
# 29997     -1  ...      20878      20582      19357         0         0
# 29998      0  ...      52774      11855      48944     85900      3409
# 29999      0  ...      36535      32428      15313      2078      1800
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  DEFAULT_NEXT_MONTH
# 29995      5003      3047      5000      1000                   0
# 29996      8998       129         0         0                   0
# 29997     22000      4200      2000      3100                   1
# 29998      1178      1926     52964      1804                   1
# 29999      1430      1000      1000      1000                   1
#
# [5 rows x 25 columns]

# %%
df.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'DEFAULT_NEXT_MONTH'],
#       dtype='object')

# %%
df.rename(columns={"DEFAULT_NEXT_MONTH":"DEFAULT"},inplace=True)

# %% [markdown]
# ## 1.3. Understanding the Dataset

# %% [markdown]
# 1. LIMIT_BAL:
# Continuous:Credit limit of the person
# 2. SEX:
# Categorical:
# 1-male
# 2-female
# 3. EDUCATION:
# Categorical:
# 1-graduate school
# 2-university
# 3-high school
# 4-others
# 5-Unknown
# 6-Unknown
# 4. MARRIAGE:
# Categorical:
# 1-married
# 2-unmarried
# 3-others
# 0-Unknown
# 5. AGE:
# Continuous:age of the card holder
# 6. PAY_0-PAY_6:
# Categorical:History of the past monthly payment records from April 2005 to September
# 2005
# "0"-No due payment
# "-1"-One due payment
# "-2"-Two due payments
# 7. BILL_AMT1-BILL_AMT6:
# Continuous:Amount of Bill Statements
# 8. PAY_AMT1-PAY_AMT6:
# Continuous:Amount of Previous Payments
# 9. DEFAULT_NEXT_MONTH:
# Categorical:Whether person is going to default or not
# 1-Default
# 0-Not Default

# %% [markdown]
# ## 1.4. Changing The Name of Column

# %%
df.rename(columns={"PAY_0":"PAY_1"},inplace=True)

# %%
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  DEFAULT
# 0         0         0         0        1
# 1      1000         0      2000        1
# 2      1000      1000      5000        0
# 3      1100      1069      1000        0
# 4      9000       689       679        0
#
# [5 rows x 25 columns]

# %% [markdown]
# ## 1.5. Cleaning EDUCATION column

# %% [markdown]
# - The variable ‘EDUCATION’ has three categories with similar information:
# - 4: others, 5: unknown, and 6: unknown 0:unknown
# - We need to group this three different categories into one single category

# %%
df["EDUCATION"].unique()
# Out:
# array([2, 1, 3, 5, 4, 6, 0], dtype=int64)

# %%
df["EDUCATION"]=np.where(df["EDUCATION"]==0, 4, df["EDUCATION"])
df["EDUCATION"]=np.where(df["EDUCATION"]==5, 4, df["EDUCATION"])
df["EDUCATION"]=np.where(df["EDUCATION"]==6, 4, df["EDUCATION"])

# %%
df["EDUCATION"].unique()
# Out:
# array([2, 1, 3, 4], dtype=int64)

# %% [markdown]
# ## 1.6. Cleaning MARRIAGE Column

# %% [markdown]
# - Similarly, the column 'marriage' should have three categories: 1 = married, 2 = single, 3 = others but it contains a category '0' which will be joined to the category '3'.

# %%
df["MARRIAGE"].unique()
# Out:
# array([1, 2, 3, 0], dtype=int64)

# %%
df["MARRIAGE"]=np.where(df["MARRIAGE"]==0, 3, df["MARRIAGE"])
df["MARRIAGE"].unique()
# Out:
# array([1, 2, 3], dtype=int64)

# %%
print("Number of Rows & Columns:",df.shape)
# Out:
# Number of Rows & Columns: (30000, 25)

# %% [markdown]
# ## 1.7. Checking The Datatypes

# %%
df.dtypes
# Out:
# ID           int64
# LIMIT_BAL    int64
# SEX          int64
# EDUCATION    int64
# MARRIAGE     int64
# AGE          int64
# PAY_1        int64
# PAY_2        int64
# PAY_3        int64
# PAY_4        int64
# PAY_5        int64
# PAY_6        int64
# BILL_AMT1    int64
# BILL_AMT2    int64
# BILL_AMT3    int64
# BILL_AMT4    int64
# BILL_AMT5    int64
# BILL_AMT6    int64
# PAY_AMT1     int64
# PAY_AMT2     int64
# PAY_AMT3     int64
# PAY_AMT4     int64
# PAY_AMT5     int64
# PAY_AMT6     int64
# DEFAULT      int64
# dtype: object

# %% [markdown]
# ## 1.8. Checking the NULL Values

# %%
df.isnull().sum()
# Out:
# ID           0
# LIMIT_BAL    0
# SEX          0
# EDUCATION    0
# MARRIAGE     0
# AGE          0
# PAY_1        0
# PAY_2        0
# PAY_3        0
# PAY_4        0
# PAY_5        0
# PAY_6        0
# BILL_AMT1    0
# BILL_AMT2    0
# BILL_AMT3    0
# BILL_AMT4    0
# BILL_AMT5    0
# BILL_AMT6    0
# PAY_AMT1     0
# PAY_AMT2     0
# PAY_AMT3     0
# PAY_AMT4     0
# PAY_AMT5     0
# PAY_AMT6     0
# DEFAULT      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         30000 non-null  int64
#  1   LIMIT_BAL  30000 non-null  int64
#  2   SEX        30000 non-null  int64
#  3   EDUCATION  30000 non-null  int64
#  4   MARRIAGE   30000 non-null  int64
#  5   AGE        30000 non-null  int64
#  6   PAY_1      30000 non-null  int64
#  7   PAY_2      30000 non-null  int64
#  8   PAY_3      30000 non-null  int64
#  9   PAY_4      30000 non-null  int64
#  10  PAY_5      30000 non-null  int64
#  11  PAY_6      30000 non-null  int64
#  12  BILL_AMT1  30000 non-null  int64
#  13  BILL_AMT2  30000 non-null  int64
#  14  BILL_AMT3  30000 non-null  int64
#  15  BILL_AMT4  30000 non-null  int64
#  16  BILL_AMT5  30000 non-null  int64
#  17  BILL_AMT6  30000 non-null  int64
#  18  PAY_AMT1   30000 non-null  int64
#  19  PAY_AMT2   30000 non-null  int64
#  20  PAY_AMT3   30000 non-null  int64
#  21  PAY_AMT4   30000 non-null  int64
#  22  PAY_AMT5   30000 non-null  int64
#  23  PAY_AMT6   30000 non-null  int64
#  24  DEFAULT    30000 non-null  int64
# dtypes: int64(25)
# memory usage: 5.7 MB

# %% [markdown]
# ## 1.9. Understanding the Minimum, Maximum, Mean, Median, Mode, Quartiles

# %%
df.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.842267      1.557267
# std     8660.398374   129747.661567      0.489129      0.744494      0.521405
# min        1.000000    10000.000000      1.000000      1.000000      1.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      4.000000      3.000000
#
#                 AGE         PAY_1         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# std        9.217904      1.123802      1.197186      1.196868      1.169139
# min       21.000000     -2.000000     -2.000000     -2.000000     -2.000000
# 25%       28.000000     -1.000000     -1.000000     -1.000000     -1.000000
# 50%       34.000000      0.000000      0.000000      0.000000      0.000000
# 75%       41.000000      0.000000      0.000000      0.000000      0.000000
# max       79.000000      8.000000      8.000000      8.000000      8.000000
#
#        ...      BILL_AMT4      BILL_AMT5      BILL_AMT6       PAY_AMT1  \
# count  ...   30000.000000   30000.000000   30000.000000   30000.000000
# mean   ...   43262.948967   40311.400967   38871.760400    5663.580500
# std    ...   64332.856134   60797.155770   59554.107537   16563.280354
# min    ... -170000.000000  -81334.000000 -339603.000000       0.000000
# 25%    ...    2326.750000    1763.000000    1256.000000    1000.000000
# 50%    ...   19052.000000   18104.500000   17071.000000    2100.000000
# 75%    ...   54506.000000   50190.500000   49198.250000    5006.000000
# max    ...  891586.000000  927171.000000  961664.000000  873552.000000
#
#            PAY_AMT2      PAY_AMT3       PAY_AMT4       PAY_AMT5  \
# count  3.000000e+04   30000.00000   30000.000000   30000.000000
# mean   5.921163e+03    5225.68150    4826.076867    4799.387633
# std    2.304087e+04   17606.96147   15666.159744   15278.305679
# min    0.000000e+00       0.00000       0.000000       0.000000
# 25%    8.330000e+02     390.00000     296.000000     252.500000
# 50%    2.009000e+03    1800.00000    1500.000000    1500.000000
# 75%    5.000000e+03    4505.00000    4013.250000    4031.500000
# max    1.684259e+06  896040.00000  621000.000000  426529.000000
#
#             PAY_AMT6       DEFAULT
# count   30000.000000  30000.000000
# mean     5215.502567      0.221200
# std     17777.465775      0.415062
# min         0.000000      0.000000
# 25%       117.750000      0.000000
# 50%      1500.000000      0.000000
# 75%      4000.000000      0.000000
# max    528666.000000      1.000000
#
# [8 rows x 25 columns]

# %% [markdown]
# ## 1.10. Understanding the Correlation Between The Dataset

# %%
df.corr()
# Out:
#                  ID  LIMIT_BAL       SEX  EDUCATION  MARRIAGE       AGE  \
# ID         1.000000   0.026179  0.018497   0.037659 -0.028208  0.018678
# LIMIT_BAL  0.026179   1.000000  0.024755  -0.231088 -0.111012  0.144713
# SEX        0.018497   0.024755  1.000000   0.013627 -0.028522 -0.090874
# EDUCATION  0.037659  -0.231088  0.013627   1.000000 -0.136797  0.182434
# MARRIAGE  -0.028208  -0.111012 -0.028522  -0.136797  1.000000 -0.412001
# AGE        0.018678   0.144713 -0.090874   0.182434 -0.412001  1.000000
# PAY_1     -0.030575  -0.271214 -0.057643   0.112593  0.018557 -0.039447
# PAY_2     -0.011215  -0.296382 -0.070771   0.129703  0.023620 -0.050148
# PAY_3     -0.018494  -0.286123 -0.066096   0.122425  0.032399 -0.053048
# PAY_4     -0.002735  -0.267460 -0.060173   0.116531  0.031831 -0.049722
# PAY_5     -0.022199  -0.249411 -0.055064   0.104088  0.034377 -0.053826
# PAY_6     -0.020270  -0.235195 -0.044008   0.088986  0.033168 -0.048773
# BILL_AMT1  0.019389   0.285430 -0.033642   0.016597 -0.027832  0.056239
# BILL_AMT2  0.017982   0.278314 -0.031183   0.011980 -0.025294  0.054283
# BILL_AMT3  0.024354   0.283236 -0.024563   0.006714 -0.029082  0.053710
# BILL_AMT4  0.040351   0.293988 -0.021880  -0.006131 -0.027274  0.051353
# BILL_AMT5  0.016705   0.295562 -0.017005  -0.012439 -0.029270  0.049345
# BILL_AMT6  0.016730   0.290389 -0.016733  -0.012646 -0.025066  0.047613
# PAY_AMT1   0.009742   0.195236 -0.000242  -0.041088 -0.004653  0.026147
# PAY_AMT2   0.008406   0.178408 -0.001391  -0.032793 -0.009513  0.021785
# PAY_AMT3   0.039151   0.210167 -0.008597  -0.044293 -0.004250  0.029247
# PAY_AMT4   0.007793   0.203242 -0.002229  -0.040949 -0.013970  0.021379
# PAY_AMT5   0.000652   0.217202 -0.001667  -0.045138 -0.003019  0.022850
# PAY_AMT6   0.003000   0.219595 -0.002766  -0.044061 -0.008383  0.019478
# DEFAULT   -0.013952  -0.153520 -0.039961   0.033842 -0.027575  0.013890
#
#               PAY_1     PAY_2     PAY_3     PAY_4  ...  BILL_AMT4  BILL_AMT5  \
# ID        -0.030575 -0.011215 -0.018494 -0.002735  ...   0.040351   0.016705
# LIMIT_BAL -0.271214 -0.296382 -0.286123 -0.267460  ...   0.293988   0.295562
# SEX       -0.057643 -0.070771 -0.066096 -0.060173  ...  -0.021880  -0.017005
# EDUCATION  0.112593  0.129703  0.122425  0.116531  ...  -0.006131  -0.012439
# MARRIAGE   0.018557  0.023620  0.032399  0.031831  ...  -0.027274  -0.029270
# AGE       -0.039447 -0.050148 -0.053048 -0.049722  ...   0.051353   0.049345
# PAY_1      1.000000  0.672164  0.574245  0.538841  ...   0.179125   0.180635
# PAY_2      0.672164  1.000000  0.766552  0.662067  ...   0.222237   0.221348
# PAY_3      0.574245  0.766552  1.000000  0.777359  ...   0.227202   0.225145
# PAY_4      0.538841  0.662067  0.777359  1.000000  ...   0.245917   0.242902
# PAY_5      0.509426  0.622780  0.686775  0.819835  ...   0.271915   0.269783
# PAY_6      0.474553  0.575501  0.632684  0.716449  ...   0.266356   0.290894
# BILL_AMT1  0.187068  0.234887  0.208473  0.202812  ...   0.860272   0.829779
# BILL_AMT2  0.189859  0.235257  0.237295  0.225816  ...   0.892482   0.859778
# BILL_AMT3  0.179785  0.224146  0.227494  0.244983  ...   0.923969   0.883910
# BILL_AMT4  0.179125  0.222237  0.227202  0.245917  ...   1.000000   0.940134
# BILL_AMT5  0.180635  0.221348  0.225145  0.242902  ...   0.940134   1.000000
# BILL_AMT6  0.176980  0.219403  0.222327  0.239154  ...   0.900941   0.946197
# PAY_AMT1  -0.079269 -0.080701  0.001295 -0.009362  ...   0.233012   0.217031
# PAY_AMT2  -0.070101 -0.058990 -0.066793 -0.001944  ...   0.207564   0.181246
# PAY_AMT3  -0.070561 -0.055901 -0.053311 -0.069235  ...   0.300023   0.252305
# PAY_AMT4  -0.064005 -0.046858 -0.046067 -0.043461  ...   0.130191   0.293118
# PAY_AMT5  -0.058190 -0.037093 -0.035863 -0.033590  ...   0.160433   0.141574
# PAY_AMT6  -0.058673 -0.036500 -0.035861 -0.026565  ...   0.177637   0.164184
# DEFAULT    0.324794  0.263551  0.235253  0.216614  ...  -0.010156  -0.006760
#
#            BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  \
# ID          0.016730  0.009742  0.008406  0.039151  0.007793  0.000652
# LIMIT_BAL   0.290389  0.195236  0.178408  0.210167  0.203242  0.217202
# SEX        -0.016733 -0.000242 -0.001391 -0.008597 -0.002229 -0.001667
# EDUCATION  -0.012646 -0.041088 -0.032793 -0.044293 -0.040949 -0.045138
# MARRIAGE   -0.025066 -0.004653 -0.009513 -0.004250 -0.013970 -0.003019
# AGE         0.047613  0.026147  0.021785  0.029247  0.021379  0.022850
# PAY_1       0.176980 -0.079269 -0.070101 -0.070561 -0.064005 -0.058190
# PAY_2       0.219403 -0.080701 -0.058990 -0.055901 -0.046858 -0.037093
# PAY_3       0.222327  0.001295 -0.066793 -0.053311 -0.046067 -0.035863
# PAY_4       0.239154 -0.009362 -0.001944 -0.069235 -0.043461 -0.033590
# PAY_5       0.262509 -0.006089 -0.003191  0.009062 -0.058299 -0.033337
# PAY_6       0.285091 -0.001496 -0.005223  0.005834  0.019018 -0.046434
# BILL_AMT1   0.802650  0.140277  0.099355  0.156887  0.158303  0.167026
# BILL_AMT2   0.831594  0.280365  0.100851  0.150718  0.147398  0.157957
# BILL_AMT3   0.853320  0.244335  0.316936  0.130011  0.143405  0.179712
# BILL_AMT4   0.900941  0.233012  0.207564  0.300023  0.130191  0.160433
# BILL_AMT5   0.946197  0.217031  0.181246  0.252305  0.293118  0.141574
# BILL_AMT6   1.000000  0.199965  0.172663  0.233770  0.250237  0.307729
# PAY_AMT1    0.199965  1.000000  0.285576  0.252191  0.199558  0.148459
# PAY_AMT2    0.172663  0.285576  1.000000  0.244770  0.180107  0.180908
# PAY_AMT3    0.233770  0.252191  0.244770  1.000000  0.216325  0.159214
# PAY_AMT4    0.250237  0.199558  0.180107  0.216325  1.000000  0.151830
# PAY_AMT5    0.307729  0.148459  0.180908  0.159214  0.151830  1.000000
# PAY_AMT6    0.115494  0.185735  0.157634  0.162740  0.157834  0.154896
# DEFAULT    -0.005372 -0.072929 -0.058579 -0.056250 -0.056827 -0.055124
#
#            PAY_AMT6   DEFAULT
# ID         0.003000 -0.013952
# LIMIT_BAL  0.219595 -0.153520
# SEX       -0.002766 -0.039961
# EDUCATION -0.044061  0.033842
# MARRIAGE  -0.008383 -0.027575
# AGE        0.019478  0.013890
# PAY_1     -0.058673  0.324794
# PAY_2     -0.036500  0.263551
# PAY_3     -0.035861  0.235253
# PAY_4     -0.026565  0.216614
# PAY_5     -0.023027  0.204149
# PAY_6     -0.025299  0.186866
# BILL_AMT1  0.179341 -0.019644
# BILL_AMT2  0.174256 -0.014193
# BILL_AMT3  0.182326 -0.014076
# BILL_AMT4  0.177637 -0.010156
# BILL_AMT5  0.164184 -0.006760
# BILL_AMT6  0.115494 -0.005372
# PAY_AMT1   0.185735 -0.072929
# PAY_AMT2   0.157634 -0.058579
# PAY_AMT3   0.162740 -0.056250
# PAY_AMT4   0.157834 -0.056827
# PAY_AMT5   0.154896 -0.055124
# PAY_AMT6   1.000000 -0.053183
# DEFAULT   -0.053183  1.000000
#
# [25 rows x 25 columns]

# %% [markdown]
# # Part 2- EDA (Exploratory Data Analysis)

# %% [markdown]
# ## 2.1. Finding The Total Defaulters

# %%
#Count of Defaulters
defaulting=df.DEFAULT.sum()
not_defaulting=len(df)-defaulting
print("Total Number of Defaulters:",defaulting)
print("Total Number of Non-Defaulters:",not_defaulting)
print("--------------------------------------------------------")
#Percentage of Defaulters
deafulter_Perc=defaulting/len(df)*100
Nondeafulter_Perc=not_defaulting/len(df)*100
print("Total Percent of Defaulters:",deafulter_Perc,"%")
print("Total Percenr of Non-Defaulters:",Nondeafulter_Perc,"%")
print("--------------------------------------------------------")
#Plotting the Piechart
pie1=np.array([deafulter_Perc,Nondeafulter_Perc])
mylabels=["Defaulters","Not-Defaulters"]
myexplode=[0.2,0]
plt.pie(pie1,labels=mylabels,shadow=True,startangle = 90,explode=myexplode,autopct="%.2f%%")
plt.legend()
plt.title("Percentage of Defaulters & Non-Defaulters")
plt.show()
# Out:
# Total Number of Defaulters: 6636
# Total Number of Non-Defaulters: 23364
# --------------------------------------------------------
# Total Percent of Defaulters: 22.12 %
# Total Percenr of Non-Defaulters: 77.88000000000001 %
# --------------------------------------------------------

# %% [markdown]
# ## 2.2. Plotting The Heatmap to Understand The Correlation Between Columns

# %%
plt.figure(figsize=(10,10))
corr = df.corr()
sns.heatmap(corr, cmap="coolwarm",linewidths=.5)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 2.3. Finding The Defaulters Based On Limit Balance Of the Card Holder

# %%
x1 = list(df[df['DEFAULT'] == 1]['LIMIT_BAL'])
x2 = list(df[df['DEFAULT'] == 0]['LIMIT_BAL'])
plt.figure(figsize=(12,4))
plt.hist([x1,x2],bins=40)
plt.xlim([0,700000])
plt.legend(['Defaulter', 'Non-Defaulter'], title = 'Default', loc='upper right', facecolor='white')
plt.grid(color="black",axis="y")
plt.xlabel("LIMIT BALANCE OF CARD HOLDER")
plt.ylabel("FREQUENCY")
plt.title("LIMIT BALANCE HISTOGRAM BY TYPE OF CREDIT CARD")
plt.show()

# %% [markdown]
# ## 2.4. Finding The Linear Realtionship Between The indepedent Variables Using The ScatterPlot

# %%
sns.scatterplot(data=df,x=df["BILL_AMT1"],y=df["BILL_AMT2"],hue="DEFAULT",palette="hls")
plt.title("Bill Amount 1 vs Bill Amount 2")
plt.show()

# %%
sns.scatterplot(data=df,x=df["BILL_AMT1"],y=df["BILL_AMT6"],hue="DEFAULT",palette="husl")
plt.title("Bill Amount 1 vs Bill Amount 6")
plt.show()

# %%
sns.scatterplot(data=df,x=df["BILL_AMT2"],y=df["BILL_AMT4"],hue="DEFAULT",palette="Paired")
plt.title("Bill Amount2 vs Bill Amount4")
plt.show()

# %%
sns.scatterplot(data=df,x=df["PAY_AMT2"],y=df["PAY_AMT4"],hue="DEFAULT",palette="Set2")
plt.title("Payment Amount2 vs Payment Amount4")
plt.show()

# %% [markdown]
# ## 2.5. Plotting The BoxPlots Using Different Variables

# %%
df1=df[["PAY_AMT1","PAY_AMT2","PAY_AMT3","PAY_AMT4","PAY_AMT5","PAY_AMT6"]] 
sns.boxplot(data=df1)
plt.ylim([-20000,200000])
plt.title("Boxplot")
plt.xticks(rotation=90)
plt.show()

# %%
df2=df[["BILL_AMT1","BILL_AMT2","BILL_AMT3","BILL_AMT4","BILL_AMT5","BILL_AMT6"]]
sns.boxplot(data=df2)
plt.ylim([-200000,1000000])
plt.title("Boxplot")
plt.xticks(rotation=90)
plt.show()

# %%
sns.boxplot(data=df,x="MARRIAGE",y="LIMIT_BAL",hue="SEX")
sns.set_style("darkgrid")
plt.ylim([0,700000])
plt.title("MARRIAGE VS LIMIT BALANCE GENDERWISE")
plt.show()

# %%
sns.boxplot(data=df,x="EDUCATION",y="LIMIT_BAL",hue="DEFAULT")
sns.set_style("darkgrid")
plt.ylim([0,700000])
plt.title("EDUCATION VS LIMIT BALANCE GENDERWISE")
plt.show()

# %% [markdown]
# ## 2.6. Plotting The Bar Chart To Find Defaulters Based On Sex, Education, Marriage

# %%
f, axes = plt.subplots(1, 3, figsize=(15,5))
sns.countplot(data=df,x="SEX",hue="DEFAULT",ax=axes[0],palette="Set2")
sns.countplot(data=df,x="EDUCATION",hue="DEFAULT",ax=axes[1],palette="husl")
sns.countplot(data=df,x="MARRIAGE",hue="DEFAULT",ax=axes[2],palette="Spectral")
plt.suptitle("SEX-EDUCATION-MARRIAGE VS DEFAULT")
plt.show()

# %% [markdown]
# ## 2.7. Plotting The Bar Charts To Find Out The Defaulters Based On The PAYMENT

# %%
f, axes = plt.subplots(2, 3, figsize=(15, 10))
f.suptitle('FREQUENCY OF CATEGORICAL VARIABLES (BY TARGET)')
sns.countplot(x="PAY_1", hue="DEFAULT", data=df, palette="rocket_r", ax=axes[0,0])
sns.countplot(x="PAY_2", hue="DEFAULT", data=df, palette="crest", ax=axes[0,1])
sns.countplot(x="PAY_3", hue="DEFAULT", data=df, palette="Spectral", ax=axes[0,2])
sns.countplot(x="PAY_4", hue="DEFAULT", data=df, palette="magma", ax=axes[1,0])
sns.countplot(x="PAY_5", hue="DEFAULT", data=df, palette="flare", ax=axes[1,1])
sns.countplot(x="PAY_6", hue="DEFAULT", data=df, palette="viridis", ax=axes[1,2])
# Out:
# <AxesSubplot:xlabel='PAY_6', ylabel='count'>

# %% [markdown]
# # Part 3- Scaling The Data Using StandardScaler

# %% [markdown]
# ## 3.1. Splitting the Dataset into Dependent Variable and Independent Variables

# %%
x=df.drop(labels=["DEFAULT"],axis=1)
y=df["DEFAULT"]

# %%
x.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0  ...        689          0          0          0         0       689
# 1  ...       2682       3272       3455       3261         0      1000
# 2  ...      13559      14331      14948      15549      1518      1500
# 3  ...      49291      28314      28959      29547      2000      2019
# 4  ...      35835      20940      19146      19131      2000     36681
#
#    PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# 0         0         0         0         0
# 1      1000      1000         0      2000
# 2      1000      1000      1000      5000
# 3      1200      1100      1069      1000
# 4     10000      9000       689       679
#
# [5 rows x 24 columns]

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    0
# 3    0
# 4    0
# Name: DEFAULT, dtype: int64

# %% [markdown]
# ## 3.2. Splitting the Dataset into Training Dataset and Testing Dataset

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7,random_state=0)

# %%
x_train
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  \
# 15925  15926      30000    2          2         2   31     -2     -2     -2
# 10062  10063     200000    1          2         1   31      1      2      2
# 19376  19377     500000    2          4         2   38     -2     -2     -2
# 6384    6385      20000    2          2         2   22      0      0      0
# 15976  15977      50000    2          2         1   48      1      2      0
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 13123  13124      30000    1          2         2   38      0      0      0
# 19648  19649     210000    2          1         1   33      0      0      0
# 9845    9846     130000    2          3         1   43      0      0      0
# 10799  10800      50000    2          3         1   29      0      0      0
# 2732    2733     140000    2          1         2   25      0      0      0
#
#        PAY_4  ...  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# 15925     -2  ...          0          0          0          0         0
# 10062      0  ...      29192      28170      28763      28453      3019
# 19376     -2  ...      24667      40626       9255       8659      2265
# 6384       0  ...      39053      20055      19606      19925      1298
# 15976      0  ...      19793      19378      18874      19361         0
# ...      ...  ...        ...        ...        ...        ...       ...
# 13123      0  ...      18432      17844      18237      10900      2100
# 19648      0  ...     192717     195700     150525     137565      7000
# 9845       0  ...      66370      43882      41063      29215      5000
# 10799      0  ...      49054       7378       8103       8963      2500
# 2732       0  ...      26006      26771      28179      29746      2000
#
#        PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# 15925         0         0         0         0         0
# 10062         6       991      1032      1310      2000
# 19376     24905     40827     30844      8695      3532
# 6384       1909      1666      5000       703       775
# 15976      2000      1500      1000      2000      1000
# ...         ...       ...       ...       ...       ...
# 13123      2500      1000      1000      3000      7002
# 19648      7791      7000      5254      5400      5380
# 9845       3000      2500      4100         0      5000
# 10799      3125       417      1000      1000       500
# 2732       2000      1500      2000      2200      2000
#
# [21000 rows x 24 columns]

# %%
x_test
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  \
# 8225    8226      20000    1          1         2   33      1      2      2
# 10794  10795      20000    2          2         2   35      0      0      2
# 9163    9164     230000    2          1         1   44      1     -1     -1
# 26591  26592     100000    1          2         1   42      0      0      0
# 6631    6632     150000    1          1         2   29     -2     -2     -2
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 21914  21915     130000    2          1         2   23      0      0      0
# 17453  17454     320000    2          1         1   36     -1      2      0
# 20344  20345     120000    2          3         1   63      0      0      0
# 1878    1879     300000    2          1         1   31     -2     -2     -1
# 6465    6466     330000    2          1         2   34      0      0      0
#
#        PAY_4  ...  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# 8225       2  ...      19057      18453      19755      19288         0
# 10794      0  ...      18600      19000      19000      20000      3400
# 9163      -1  ...       2864        933          0          0       949
# 26591      0  ...      16138      17758      18774      20272      5000
# 6631      -2  ...        831       6469       5138       7810      6989
# ...      ...  ...        ...        ...        ...        ...       ...
# 21914      0  ...      93977      94427      89041      89833      4500
# 17453      0  ...      13355      16876      20443      24101         0
# 20344      0  ...      51333      51174      44680      43760      3000
# 1878       0  ...      12192       7639       1722       4064      1110
# 6465       0  ...     228275     227974     185431     107493     15000
#
#        PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# 8225       2260         0      1600         0       644
# 10794         0      1000         0      1000         0
# 9163       2873       933         0         0         0
# 26591      2000      2000      2000      2000      2000
# 6631        833      6488      5153      7833      7130
# ...         ...       ...       ...       ...       ...
# 21914      4363      3300      3178      3178      3424
# 17453      8000      5000      5000      5000     11906
# 20344      2000      2000      2000      2000      2000
# 1878      12192       300       191      4064       390
# 6465      10008     10000     20000     25000      3500
#
# [9000 rows x 24 columns]

# %%
y_train
# Out:
# 15925    0
# 10062    0
# 19376    0
# 6384     0
# 15976    1
#         ..
# 13123    0
# 19648    1
# 9845     0
# 10799    0
# 2732     0
# Name: DEFAULT, Length: 21000, dtype: int64

# %%
y_test
# Out:
# 8225     0
# 10794    0
# 9163     0
# 26591    0
# 6631     0
#         ..
# 21914    0
# 17453    0
# 20344    0
# 1878     0
# 6465     0
# Name: DEFAULT, Length: 9000, dtype: int64

# %% [markdown]
# ## 3.3. Scaling the Training Dataset Using StandardScaler

# %%
from sklearn.preprocessing import StandardScaler
train_scaler=StandardScaler()
test_scaler=StandardScaler()

# %%
scaled_train_data=train_scaler.fit_transform(x_train)
scaled_train_data=pd.DataFrame(data=scaled_train_data,columns=x_train.columns,index=x_train.index)
scaled_train_data
# Out:
#              ID  LIMIT_BAL       SEX  EDUCATION  MARRIAGE       AGE     PAY_1  \
# 15925  0.111359  -1.063195  0.817793   0.212872  0.848088 -0.485236 -1.756704
# 10062 -0.566792   0.253364 -1.222803   0.212872 -1.071904 -0.485236  0.890707
# 19376  0.510524   2.576705  0.817793   2.900159  0.848088  0.276931 -1.756704
# 6384  -0.992213  -1.140640  0.817793   0.212872  0.848088 -1.465165  0.008236
# 15976  0.117258  -0.908306  0.817793   0.212872 -1.071904  1.365741  0.890707
# ...         ...        ...       ...        ...       ...       ...       ...
# 13123 -0.212737  -1.063195 -1.222803   0.212872  0.848088  0.276931  0.008236
# 19648  0.541985   0.330809  0.817793  -1.130772 -1.071904 -0.267474  0.008236
# 9845  -0.591892  -0.288748  0.817793   1.556515 -1.071904  0.821336  0.008236
# 10799 -0.481546  -0.908306  0.817793   1.556515 -1.071904 -0.702998  0.008236
# 2732  -1.414626  -0.211304  0.817793  -1.130772  0.848088 -1.138522  0.008236
#
#           PAY_2     PAY_3     PAY_4  ...  BILL_AMT3  BILL_AMT4  BILL_AMT5  \
# 15925 -1.554090 -1.526818 -1.523691  ...  -0.678262  -0.675090  -0.668727
# 10062  1.756174  1.785922  0.180389  ...  -0.256966  -0.233607  -0.190694
# 19376 -1.554090 -1.526818 -1.523691  ...  -0.322270  -0.038395  -0.514911
# 6384   0.101042  0.129552  0.180389  ...  -0.114653  -0.360786  -0.342881
# 15976  1.756174  0.129552  0.180389  ...  -0.392611  -0.371396  -0.355046
# ...         ...       ...       ...  ...        ...        ...        ...
# 13123  0.101042  0.129552  0.180389  ...  -0.412253  -0.395437  -0.365633
# 19648  0.101042  0.129552  0.180389  ...   2.103010   2.391943   1.832954
# 9845   0.101042  0.129552  0.180389  ...   0.279583   0.012634   0.013728
# 10799  0.101042  0.129552  0.180389  ...   0.029681  -0.559461  -0.534057
# 2732   0.101042  0.129552  0.180389  ...  -0.302946  -0.255532  -0.200400
#
#        BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# 15925  -0.656920 -0.334535 -0.245768 -0.301666 -0.311311 -0.316269 -0.297365
# 10062  -0.175440 -0.156089 -0.245520 -0.243881 -0.245227 -0.229656 -0.183567
# 19376  -0.510393 -0.200656  0.783499  2.078955  1.663779  0.258613 -0.096398
# 6384   -0.319751 -0.257813 -0.166874 -0.204522  0.008863 -0.269789 -0.253268
# 15976  -0.329295 -0.334535 -0.163113 -0.214201 -0.247276 -0.184036 -0.240466
# ...          ...       ...       ...       ...       ...       ...       ...
# 13123  -0.472471 -0.210409 -0.142449 -0.243356 -0.247276 -0.117920  0.101042
# 19648   1.670946  0.079218  0.076216  0.106504  0.025128  0.040760  0.008752
# 9845   -0.162546 -0.038997 -0.121785 -0.155891 -0.048768 -0.316269 -0.012870
# 10799  -0.505249 -0.186766 -0.116619 -0.277351 -0.247276 -0.250152 -0.268915
# 2732   -0.153560 -0.216320 -0.163113 -0.214201 -0.183241 -0.170813 -0.183567
#
# [21000 rows x 24 columns]

# %% [markdown]
# ## 3.4. Scaling the Testing Dataset StandardScaler

# %%
pd.set_option("display.max_columns",30)
scaled_test_data=test_scaler.fit_transform(x_test)
scaled_test_data=pd.DataFrame(data=scaled_test_data,columns=x_test.columns,index=x_test.index)
scaled_test_data
# Out:
#              ID  LIMIT_BAL       SEX  EDUCATION  MARRIAGE       AGE    PAY_1  \
# 8225  -0.789233  -1.127827 -1.261811  -1.132687  0.851570 -0.274667  0.93875
# 10794 -0.493736  -1.127827  0.792512   0.209536  0.851570 -0.059495  0.03077
# 9163  -0.681341   0.473002  0.792512  -1.132687 -1.061593  0.908779  0.93875
# 26591  1.323302  -0.517987 -1.261811   0.209536 -1.061593  0.693607  0.03077
# 6631  -0.972582  -0.136838 -1.261811  -1.132687  0.851570 -0.705011 -1.78519
# ...         ...        ...       ...        ...       ...       ...      ...
# 21914  0.785334  -0.289298  0.792512  -1.132687  0.851570 -1.350527  0.03077
# 17453  0.272210   1.159071  0.792512  -1.132687 -1.061593  0.048091 -0.87721
# 20344  0.604745  -0.365528  0.792512   1.551759 -1.061593  2.952913  0.03077
# 1878  -1.519292   1.006611  0.792512  -1.132687 -1.061593 -0.489839 -1.78519
# 6465  -0.991676   1.235301  0.792512  -1.132687  0.851570 -0.167081  0.03077
#
#           PAY_2     PAY_3     PAY_4     PAY_5     PAY_6  BILL_AMT1  BILL_AMT2  \
# 8225   1.846738  1.868711  1.935378  2.031109  2.031522  -0.444023  -0.441792
# 10794  0.137587  1.868711  0.208561  0.253247  0.274741  -0.463294  -0.414947
# 9163  -0.716989 -0.692337 -0.654847 -0.635684 -1.482040  -0.632156  -0.668486
# 26591  0.137587  0.161346  0.208561  0.253247  0.274741   0.630513   0.696487
# 6631  -1.571565 -1.546019 -1.518255 -1.524615 -1.482040  -0.622820  -0.586242
# ...         ...       ...       ...       ...       ...        ...        ...
# 21914  0.137587  0.161346  0.208561  0.253247  0.274741   0.679353   0.711384
# 17453  1.846738  0.161346  0.208561  0.253247  0.274741  -0.578949  -0.588847
# 20344  0.137587  0.161346  0.208561  0.253247  0.274741  -0.024366   0.024853
# 1878  -1.571565 -0.692337  0.208561  0.253247  0.274741  -0.684027  -0.666267
# 6465   0.137587  0.161346  0.208561  0.253247  0.274741   2.814656   2.706883
#
#        BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 8225   -0.402882  -0.385227  -0.333102  -0.325086 -0.361243 -0.179304
# 10794  -0.409459  -0.376881  -0.345234  -0.313339 -0.144719 -0.291826
# 9163   -0.635936  -0.652559  -0.650537  -0.643324 -0.300807 -0.148783
# 26591  -0.444893  -0.395832  -0.348865  -0.308851 -0.042826 -0.192249
# 6631   -0.665196  -0.568087  -0.567976  -0.514465  0.083841 -0.250352
# ...          ...        ...        ...        ...       ...       ...
# 21914   0.675388   0.774035   0.780225   0.838855 -0.074667 -0.074599
# 17453  -0.484947  -0.409290  -0.322047  -0.245675 -0.361243  0.106482
# 20344   0.061643   0.114052   0.067407   0.078684 -0.170193 -0.192249
# 1878   -0.501685  -0.550234  -0.622867  -0.576271 -0.290554  0.315195
# 6465    2.608243   2.811784   2.329075   1.130233  0.594009  0.206457
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# 8225  -0.287054 -0.199188 -0.309439 -0.249261
# 10794 -0.233374 -0.300580 -0.245458 -0.284568
# 9163  -0.236970 -0.300580 -0.309439 -0.284568
# 26591 -0.179693 -0.173839 -0.181477 -0.174920
# 6631   0.061225  0.025968  0.191724  0.106328
# ...         ...       ...       ...       ...
# 21914 -0.109909 -0.099189 -0.106108 -0.096850
# 17453 -0.018652  0.016272  0.010466  0.368168
# 20344 -0.179693 -0.173839 -0.181477 -0.174920
# 1878  -0.270950 -0.288476 -0.049420 -0.263187
# 6465   0.249750  0.966828  1.290086 -0.092684
#
# [9000 rows x 24 columns]

# %% [markdown]
# # Part 4- Feature Selection Using mutual_info_classifier

# %% [markdown]
# ## 4.1. Calculating the Mutual Information Of every Feature

# %%
from sklearn.feature_selection import mutual_info_classif
info_gain1=mutual_info_classif(scaled_train_data,y_train)
info_gain1
# Out:
# array([0.00391419, 0.01244723, 0.00394856, 0.0011497 , 0.00141394,
#        0.00597356, 0.07464277, 0.04904298, 0.04008525, 0.03558466,
#        0.03448087, 0.02970031, 0.00733529, 0.00617755, 0.00268098,
#        0.00179968, 0.00817509, 0.00787441, 0.02301144, 0.01321951,
#        0.01899506, 0.01344037, 0.01790772, 0.01119524])

# %%
data={"Column_Name":x_train.columns,"Mutual_Information":info_gain1}
gain1=pd.DataFrame(data)
gain1
# Out:
#    Column_Name  Mutual_Information
# 0           ID            0.003914
# 1    LIMIT_BAL            0.012447
# 2          SEX            0.003949
# 3    EDUCATION            0.001150
# 4     MARRIAGE            0.001414
# 5          AGE            0.005974
# 6        PAY_1            0.074643
# 7        PAY_2            0.049043
# 8        PAY_3            0.040085
# 9        PAY_4            0.035585
# 10       PAY_5            0.034481
# 11       PAY_6            0.029700
# 12   BILL_AMT1            0.007335
# 13   BILL_AMT2            0.006178
# 14   BILL_AMT3            0.002681
# 15   BILL_AMT4            0.001800
# 16   BILL_AMT5            0.008175
# 17   BILL_AMT6            0.007874
# 18    PAY_AMT1            0.023011
# 19    PAY_AMT2            0.013220
# 20    PAY_AMT3            0.018995
# 21    PAY_AMT4            0.013440
# 22    PAY_AMT5            0.017908
# 23    PAY_AMT6            0.011195

# %%
sns.barplot(data=gain1,x="Column_Name",y="Mutual_Information",palette="Set2",order=gain1.sort_values("Mutual_Information",ascending = False).Column_Name)
plt.xticks(rotation=90)
plt.title("Column Wise Mutual Information")
plt.grid(color="black",axis="y")
plt.show()

# %% [markdown]
# ## 4.2. Selecting the Top-11 Features for the Model Building

# %%
from sklearn.feature_selection import SelectKBest
eleven_col=SelectKBest(mutual_info_classif,k=11)
eleven_col.fit(scaled_train_data,y_train)
scaled_train_data.columns[eleven_col.get_support()]
# Out:
# Index(['LIMIT_BAL', 'PAY_1', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6',
#        'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT5'],
#       dtype='object')

# %% [markdown]
# ## 4.3. Training Dataset

# %%
scaled_train_fs_data=eleven_col.transform(scaled_train_data)
scaled_train_fs_data=pd.DataFrame(scaled_train_fs_data,columns=scaled_train_data.columns[eleven_col.get_support()],index=scaled_train_data.index)
scaled_train_fs_data
# Out:
#        LIMIT_BAL     PAY_1     PAY_2     PAY_3     PAY_4     PAY_5     PAY_6  \
# 15925  -1.063195 -1.756704 -1.554090 -1.526818 -1.523691 -1.532501 -1.487937
# 10062   0.253364  0.890707  1.756174  1.785922  0.180389  0.227164  0.244044
# 19376   2.576705 -1.756704 -1.554090 -1.526818 -1.523691 -1.532501 -1.487937
# 6384   -1.140640  0.008236  0.101042  0.129552  0.180389  0.227164  0.244044
# 15976  -0.908306  0.890707  1.756174  0.129552  0.180389  0.227164  0.244044
# ...          ...       ...       ...       ...       ...       ...       ...
# 13123  -1.063195  0.008236  0.101042  0.129552  0.180389  0.227164  0.244044
# 19648   0.330809  0.008236  0.101042  0.129552  0.180389  0.227164  0.244044
# 9845   -0.288748  0.008236  0.101042  0.129552  0.180389  0.227164  1.976026
# 10799  -0.908306  0.008236  0.101042  0.129552  0.180389  0.227164  0.244044
# 2732   -0.211304  0.008236  0.101042  0.129552  0.180389  0.227164  0.244044
#
#        PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT5
# 15925 -0.334535 -0.245768 -0.301666 -0.316269
# 10062 -0.156089 -0.245520 -0.243881 -0.229656
# 19376 -0.200656  0.783499  2.078955  0.258613
# 6384  -0.257813 -0.166874 -0.204522 -0.269789
# 15976 -0.334535 -0.163113 -0.214201 -0.184036
# ...         ...       ...       ...       ...
# 13123 -0.210409 -0.142449 -0.243356 -0.117920
# 19648  0.079218  0.076216  0.106504  0.040760
# 9845  -0.038997 -0.121785 -0.155891 -0.316269
# 10799 -0.186766 -0.116619 -0.277351 -0.250152
# 2732  -0.216320 -0.163113 -0.214201 -0.170813
#
# [21000 rows x 11 columns]

# %% [markdown]
# ## 4.4. Testing Dataset

# %%
scaled_test_fs_data=eleven_col.transform(scaled_test_data)
scaled_test_fs_data=pd.DataFrame(scaled_test_fs_data,columns=scaled_test_data.columns[eleven_col.get_support()],index=scaled_test_data.index)
scaled_test_fs_data
# Out:
#        LIMIT_BAL    PAY_1     PAY_2     PAY_3     PAY_4     PAY_5     PAY_6  \
# 8225   -1.127827  0.93875  1.846738  1.868711  1.935378  2.031109  2.031522
# 10794  -1.127827  0.03077  0.137587  1.868711  0.208561  0.253247  0.274741
# 9163    0.473002  0.93875 -0.716989 -0.692337 -0.654847 -0.635684 -1.482040
# 26591  -0.517987  0.03077  0.137587  0.161346  0.208561  0.253247  0.274741
# 6631   -0.136838 -1.78519 -1.571565 -1.546019 -1.518255 -1.524615 -1.482040
# ...          ...      ...       ...       ...       ...       ...       ...
# 21914  -0.289298  0.03077  0.137587  0.161346  0.208561  0.253247  0.274741
# 17453   1.159071 -0.87721  1.846738  0.161346  0.208561  0.253247  0.274741
# 20344  -0.365528  0.03077  0.137587  0.161346  0.208561  0.253247  0.274741
# 1878    1.006611 -1.78519 -1.571565 -0.692337  0.208561  0.253247  0.274741
# 6465    1.235301  0.03077  0.137587  0.161346  0.208561  0.253247  0.274741
#
#        PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT5
# 8225  -0.361243 -0.179304 -0.287054 -0.309439
# 10794 -0.144719 -0.291826 -0.233374 -0.245458
# 9163  -0.300807 -0.148783 -0.236970 -0.309439
# 26591 -0.042826 -0.192249 -0.179693 -0.181477
# 6631   0.083841 -0.250352  0.061225  0.191724
# ...         ...       ...       ...       ...
# 21914 -0.074667 -0.074599 -0.109909 -0.106108
# 17453 -0.361243  0.106482 -0.018652  0.010466
# 20344 -0.170193 -0.192249 -0.179693 -0.181477
# 1878  -0.290554  0.315195 -0.270950 -0.049420
# 6465   0.594009  0.206457  0.249750  1.290086
#
# [9000 rows x 11 columns]

# %% [markdown]
# # Part 5- Applying Machine Learning Algorithms

# %% [markdown]
# ## 5.1. Logistic Regression

# %%
import sys
from sklearn.linear_model import LogisticRegression
model_lr=LogisticRegression()
model_lr.fit(scaled_train_fs_data,y_train)
y_pred_logreg=model_lr.predict(scaled_test_fs_data)

# %%
info={"Actual Value":y_test,"Predicted Value":y_pred_logreg}
logreg=pd.DataFrame(info)
logreg.tail(18)
# Out:
#        Actual Value  Predicted Value
# 7553              0                0
# 12063             0                0
# 11607             0                0
# 22038             0                0
# 26598             1                0
# 14600             0                0
# 20945             0                0
# 1310              1                1
# 28352             0                0
# 23682             0                0
# 21383             0                0
# 675               1                1
# 21313             0                0
# 21914             0                0
# 17453             0                0
# 20344             0                0
# 1878              0                0
# 6465              0                0

# %% [markdown]
# ## 5.2. SVM (Support Vector Machine)

# %%
from sklearn.svm import SVC
model_svm=SVC()
model_svm.fit(scaled_train_fs_data,y_train)
y_pred_svm=model_svm.predict(scaled_test_fs_data)

# %%
info={"Actual Value":y_test,"Predicted Value":y_pred_svm}
svm=pd.DataFrame(info)
svm.sample(18)
# Out:
#        Actual Value  Predicted Value
# 21883             0                0
# 12855             0                0
# 8384              0                0
# 6682              1                0
# 24107             0                0
# 20859             0                0
# 29520             1                0
# 6498              0                0
# 10440             0                0
# 19202             0                0
# 17826             0                0
# 1379              0                1
# 4502              1                0
# 19189             1                0
# 28878             0                0
# 13235             1                0
# 18657             0                1
# 1242              0                0

# %% [markdown]
# ## 5.3. Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
model_navbay=GaussianNB()
model_navbay.fit(scaled_train_fs_data,y_train)
y_pred_navbay=model_navbay.predict(scaled_test_fs_data)

# %%
info={"Actual Value":y_test,"Predicted Value":y_pred_navbay}
NB=pd.DataFrame(info)
NB.sample(18)
# Out:
#        Actual Value  Predicted Value
# 6698              0                0
# 10117             0                0
# 26661             0                1
# 14264             0                0
# 27644             0                0
# 1886              0                0
# 4866              1                1
# 20053             1                0
# 20263             0                1
# 21042             0                0
# 5049              0                1
# 153               0                0
# 6425              0                0
# 1556              0                0
# 1041              1                1
# 1624              0                0
# 13670             0                0
# 29292             1                1

# %% [markdown]
# ## 5.4. KNN (K-Nearest Neighbours)

# %%
from sklearn.neighbors import KNeighborsClassifier
model_knn=KNeighborsClassifier()
model_knn.fit(scaled_train_fs_data,y_train)
y_pred_KNN=model_knn.predict(scaled_test_fs_data)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
info={"Actual Value":y_test,"Predicted Value":y_pred_KNN}
KNN=pd.DataFrame(info)
KNN.sample(18)
# Out:
#        Actual Value  Predicted Value
# 3468              0                0
# 15248             0                0
# 4663              0                0
# 2639              0                0
# 12698             0                0
# 8955              0                0
# 20098             0                0
# 1751              1                1
# 28811             0                0
# 14166             0                0
# 21276             0                0
# 24195             0                0
# 1797              0                0
# 28869             0                0
# 17757             0                0
# 18046             0                0
# 2956              1                0
# 11695             0                0

# %% [markdown]
# ## 5.5. Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
model_dt=DecisionTreeClassifier()
model_dt.fit(scaled_train_fs_data,y_train)
y_pred_DT=model_dt.predict(scaled_test_fs_data)

# %%
info={"Actual Value":y_test,"Predicted Value":y_pred_DT}
DT=pd.DataFrame(info)
DT.sample(18)
# Out:
#        Actual Value  Predicted Value
# 25103             0                0
# 3239              0                1
# 27301             0                0
# 7638              0                0
# 27648             0                0
# 22823             0                1
# 20708             0                0
# 3641              0                0
# 18378             0                0
# 15205             0                0
# 29340             0                0
# 17862             1                1
# 7104              0                0
# 9706              1                1
# 17888             0                0
# 13489             0                0
# 8859              1                0
# 29891             0                1

# %% [markdown]
# ## 5.6. Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
model_rf=RandomForestClassifier(n_estimators=100)
model_rf.fit(scaled_train_fs_data,y_train)
y_pred_RF=model_rf.predict(scaled_test_fs_data)

# %%
info={"Actual Value":y_test,"Predicted Value":y_pred_RF}
RF=pd.DataFrame(info)
RF.sample(18)
# Out:
#        Actual Value  Predicted Value
# 8513              1                0
# 18304             0                0
# 21024             0                0
# 18053             0                0
# 22651             0                0
# 17908             1                1
# 18120             0                0
# 22242             0                0
# 20684             1                1
# 15656             0                0
# 22055             0                1
# 28066             0                0
# 27937             1                0
# 21463             1                1
# 3659              0                0
# 27467             1                1
# 1984              0                0
# 11148             0                0

# %% [markdown]
# ## 5.7. XG Boost (eXtreme Gradient Boosting)

# %%
from xgboost import XGBClassifier
model_xgb=XGBClassifier(n_estimators=500)
model_xgb.fit(scaled_train_fs_data,y_train)
y_pred_XGB=model_xgb.predict(scaled_test_fs_data)

# %%
info={"Actual Value":y_test,"Predicted Value":y_pred_XGB}
XGB=pd.DataFrame(info)
XGB.sample(18)
# Out:
#        Actual Value  Predicted Value
# 23643             0                0
# 14749             0                0
# 27817             0                0
# 1847              1                0
# 28613             0                0
# 20257             1                0
# 25622             0                1
# 15626             0                0
# 22401             1                1
# 14486             0                0
# 29500             1                1
# 8811              1                1
# 17970             0                0
# 7416              0                1
# 23240             0                0
# 9807              0                0
# 23844             0                0
# 10125             0                0

# %% [markdown]
# ## 5.8. ANN (Artificial Neural Network) Using TensorFlow & Keras

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense
model_ann=Sequential()
model_ann.add(Dense(12,input_dim=11,activation="sigmoid"))
model_ann.add(Dense(10,activation="relu"))
model_ann.add(Dense(8,activation="relu"))
model_ann.add(Dense(3,activation="sigmoid"))
model_ann.add(Dense(1,activation="relu"))
model_ann.compile(optimizer="Adam",loss="binary_crossentropy",metrics=["accuracy"])
history=model_ann.fit(scaled_train_fs_data,y_train,epochs=100,verbose=1)
# Out:
# Epoch 1/100
# 657/657 [==============================] - 4s 3ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 2/100
# 657/657 [==============================] - 2s 3ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 3/100
# 657/657 [==============================] - 2s 3ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 4/100
# 657/657 [==============================] - 2s 3ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 5/100
# 657/657 [==============================] - 2s 3ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 6/100
# 657/657 [==============================] - 2s 3ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 7/100
# 657/657 [==============================] - 2s 3ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 8/100
# 657/657 [==============================] - 2s 3ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 9/100
# 657/657 [==============================] - 2s 3ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 10/100
# 657/657 [==============================] - 2s 3ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 11/100
# 657/657 [==============================] - 2s 3ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 12/100
# 657/657 [==============================] - 2s 3ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 13/100
# 657/657 [==============================] - 2s 3ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 14/100
# 657/657 [==============================] - 2s 3ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 15/100
# 657/657 [==============================] - 2s 3ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 16/100
# 657/657 [==============================] - 2s 3ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 17/100
# 657/657 [==============================] - 2s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 18/100
# 657/657 [==============================] - 2s 3ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 19/100
# 657/657 [==============================] - 2s 3ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 20/100
# 657/657 [==============================] - 2s 3ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 21/100
# 657/657 [==============================] - 2s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 22/100
# 657/657 [==============================] - 2s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 23/100
# 657/657 [==============================] - 2s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 24/100
# 657/657 [==============================] - 2s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 25/100
# 657/657 [==============================] - 2s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 26/100
# 657/657 [==============================] - 2s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 27/100
# 657/657 [==============================] - 2s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 28/100
# 657/657 [==============================] - 2s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 29/100
# 657/657 [==============================] - 2s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 30/100
# 657/657 [==============================] - 1s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 31/100
# 657/657 [==============================] - 2s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 32/100
# 657/657 [==============================] - 2s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 33/100
# 657/657 [==============================] - 1s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 34/100
# 657/657 [==============================] - 1s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 35/100
# 657/657 [==============================] - 1s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 36/100
# 657/657 [==============================] - 2s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 37/100
# 657/657 [==============================] - 1s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 38/100
# 657/657 [==============================] - 2s 3ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 39/100
# 657/657 [==============================] - 2s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 40/100
# 657/657 [==============================] - 1s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 41/100
# 657/657 [==============================] - 1s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 42/100
# 657/657 [==============================] - 1s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 43/100
# 657/657 [==============================] - 1s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 44/100
# 657/657 [==============================] - 1s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 45/100
# 657/657 [==============================] - 1s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 46/100
# 657/657 [==============================] - 2s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 47/100
# 657/657 [==============================] - 1s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 48/100
# 657/657 [==============================] - 1s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 49/100
# 657/657 [==============================] - 2s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 50/100
# 657/657 [==============================] - 1s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 51/100
# 657/657 [==============================] - 1s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 52/100
# 657/657 [==============================] - 1s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 53/100
# 657/657 [==============================] - 1s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 54/100
# 657/657 [==============================] - 1s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 55/100
# 657/657 [==============================] - 1s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 56/100
# 657/657 [==============================] - 1s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 57/100
# 657/657 [==============================] - 1s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 58/100
# 657/657 [==============================] - 1s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 59/100
# 657/657 [==============================] - 1s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 60/100
# 657/657 [==============================] - 1s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 61/100
# 657/657 [==============================] - 1s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 62/100
# 657/657 [==============================] - 1s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 63/100
# 657/657 [==============================] - 1s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 64/100
# 657/657 [==============================] - 1s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 65/100
# 657/657 [==============================] - 2s 3ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 66/100
# 657/657 [==============================] - 2s 3ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 67/100
# 657/657 [==============================] - 2s 3ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 68/100
# 657/657 [==============================] - 2s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 69/100
# 657/657 [==============================] - 2s 3ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 70/100
# 657/657 [==============================] - 2s 3ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 71/100
# 657/657 [==============================] - 2s 3ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 72/100
# 657/657 [==============================] - 2s 3ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 73/100
# 657/657 [==============================] - 2s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 74/100
# 657/657 [==============================] - 2s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 75/100
# 657/657 [==============================] - 2s 3ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 76/100
# 657/657 [==============================] - 2s 3ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 77/100
# 657/657 [==============================] - 2s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 78/100
# 657/657 [==============================] - 2s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 79/100
# 657/657 [==============================] - 2s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 80/100
# 657/657 [==============================] - 2s 3ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 81/100
# 657/657 [==============================] - 1s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 82/100
# 657/657 [==============================] - 1s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 83/100
# 657/657 [==============================] - 1s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 84/100
# 657/657 [==============================] - 1s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 85/100
# 657/657 [==============================] - 1s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 86/100
# 657/657 [==============================] - 1s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 87/100
# 657/657 [==============================] - 2s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 88/100
# 657/657 [==============================] - 1s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 89/100
# 657/657 [==============================] - 1s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 90/100
# 657/657 [==============================] - 1s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 91/100
# 657/657 [==============================] - 1s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 92/100
# 657/657 [==============================] - 2s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 93/100
# 657/657 [==============================] - 2s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 94/100
# 657/657 [==============================] - 2s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 95/100
# 657/657 [==============================] - 1s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 96/100
# 657/657 [==============================] - 2s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 97/100
# 657/657 [==============================] - 2s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 98/100
# 657/657 [==============================] - 2s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 99/100
# 657/657 [==============================] - 2s 2ms/step - loss: 3.4493 - accuracy: 0.7764
# Epoch 100/100
# 657/657 [==============================] - 2s 2ms/step - loss: 3.4493 - accuracy: 0.7764

# %%
acc=model_ann.evaluate(scaled_test_fs_data,y_test)
acc
# Out:
# 282/282 [==============================] - 1s 2ms/step - loss: 3.3249 - accuracy: 0.7844
# [3.324932336807251, 0.7844444513320923]

# %%
y_pred_ann=model_ann.predict(scaled_test_fs_data)
# Out:
# 282/282 [==============================] - 1s 2ms/step

# %%
plt.plot(history.history['accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# %% [markdown]
# # Part 6- Evaluating The Performance of Algorithms

# %% [markdown]
# ## 6.1. Accuracy Score

# %%
from sklearn.metrics import accuracy_score
lr_as=accuracy_score(y_test,y_pred_logreg)
svm_as=accuracy_score(y_test,y_pred_svm)
nb_as=accuracy_score(y_test,y_pred_navbay)
knn_as=accuracy_score(y_test,y_pred_KNN)
dt_as=accuracy_score(y_test,y_pred_DT)
rf_as=accuracy_score(y_test,y_pred_RF)
xgb_as=accuracy_score(y_test,y_pred_XGB)
print("Accuracy score - Logistic Regression:",lr_as*100)
print("Accuracy score - SVM:",svm_as*100)
print("Accuracy score - Naive Bayes:",nb_as*100)
print("Accuracy score - KNN:",knn_as*100)
print("Accuracy score - Decision Tree:",dt_as*100)
print("Accuracy score - Random Forest:",rf_as*100)
print("Accuracy score - XGBoost:",xgb_as*100)
print("Accuracy score - ANN:",acc[1]*100)
# Out:
# Accuracy score - Logistic Regression: 81.64444444444445
# Accuracy score - SVM: 82.46666666666667
# Accuracy score - Naive Bayes: 76.1
# Accuracy score - KNN: 80.27777777777779
# Accuracy score - Decision Tree: 71.83333333333334
# Accuracy score - Random Forest: 81.87777777777778
# Accuracy score - XGBoost: 80.36666666666666
# Accuracy score - ANN: 78.44444513320923

# %% [markdown]
# ## 6.2. F1_Score

# %%
from sklearn.metrics import f1_score
lr_fs=f1_score(y_test,y_pred_logreg,average="weighted")
svm_fs=f1_score(y_test,y_pred_svm,average="weighted")
nb_fs=f1_score(y_test,y_pred_navbay,average="weighted")
knn_fs=f1_score(y_test,y_pred_KNN,average="weighted")
dt_fs=f1_score(y_test,y_pred_DT,average="weighted")
rf_fs=f1_score(y_test,y_pred_RF,average="weighted")
xgb_fs=f1_score(y_test,y_pred_XGB,average="weighted")
print("F1 Score - Logistic Regression:",lr_fs*100)
print("F1 Score - SVM:",svm_fs*100)
print("F1 Score - Naive Bayes:",nb_fs*100)
print("F1 Score - KNN:",knn_fs*100)
print("F1 Score - Decision Tree:",dt_fs*100)
print("F1 Score - Random Forest:",rf_fs*100)
print("F1 Score - XGBoost:",xgb_fs*100)
# Out:
# F1 Score - Logistic Regression: 77.71630706983484
# F1 Score - SVM: 80.3047447864442
# F1 Score - Naive Bayes: 77.1294022400434
# F1 Score - KNN: 78.66933208974002
# F1 Score - Decision Tree: 72.20865469455683
# F1 Score - Random Forest: 79.54975707260738
# F1 Score - XGBoost: 77.85967009852762

# %% [markdown]
# ## 6.3. Creating The Dataframe Of the Performance Metrics

# %%
data={"Accuracy Score":[lr_as,svm_as,nb_as,knn_as,dt_as,rf_as,xgb_as,acc[1]], "F1_Score":[lr_fs,svm_fs,nb_fs,knn_fs,dt_fs,rf_fs,xgb_fs,acc[1]]}
table1=pd.DataFrame(data,index=["Logistic Regression","Support Vector Machine","Naive Bayes","K-Nearest Neighbour","Decision Tree","Random Forest","XG Boost","ANN"])
table1
# Out:
#                         Accuracy Score  F1_Score
# Logistic Regression           0.816444  0.777163
# Support Vector Machine        0.824667  0.803047
# Naive Bayes                   0.761000  0.771294
# K-Nearest Neighbour           0.802778  0.786693
# Decision Tree                 0.718333  0.722087
# Random Forest                 0.818778  0.795498
# XG Boost                      0.803667  0.778597
# ANN                           0.784444  0.784444

# %% [markdown]
# ## 6.4. Plotting The Performance Of All The Algorithms Using Line Chart

# %%
sns.lineplot(data = table1, markers=True, dashes=True)
plt.xticks(rotation=90)
plt.grid(color="black")
plt.xlabel("Machine Learning Algorithms Performance")
plt.ylabel("Score")
plt.title("Comparing the Accuracy & F1 Scores of different Algorithms")
plt.show()

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# # After performing 9 algorithms we can clearly conclude that out of nine algorithms following 2 are the best performing algorithms
# ## 1. SVM (Support Vector Machine)
# ## 2. ANN (Artificial Neural Network)
